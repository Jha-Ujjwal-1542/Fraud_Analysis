# %%
import pandas as pd
import glob

# %%
csv_directory = "./fraud_data_analysis_data/"

# %%
# Get a list of all CSV files in the directory
csv_files = glob.glob(csv_directory + "*.csv")

# %%
csv_files
# Out:
# ['./fraud_data_analysis_data/Train_Outpatientdata-1542865627584.csv',
#  './fraud_data_analysis_data/Train_Beneficiarydata-1542865627584.csv',
#  './fraud_data_analysis_data/Test_Beneficiarydata-1542969243754.csv',
#  './fraud_data_analysis_data/Test_Inpatientdata-1542969243754.csv',
#  './fraud_data_analysis_data/Test-1542969243754.csv',
#  './fraud_data_analysis_data/Train_Inpatientdata-1542865627584.csv',
#  './fraud_data_analysis_data/Test_Outpatientdata-1542969243754.csv',
#  './fraud_data_analysis_data/Train-1542865627584.csv']

# %% [markdown]
# # Dictionary

# %%
# Dictionary to store the dataframes
dataframes_dict = {}

# %%
# Read each CSV file and store in a separate variable
for file_name in csv_files:
    print(file_name)
# Out:
# ./fraud_data_analysis_data/Train_Outpatientdata-1542865627584.csv
# ./fraud_data_analysis_data/Train_Beneficiarydata-1542865627584.csv
# ./fraud_data_analysis_data/Test_Beneficiarydata-1542969243754.csv
# ./fraud_data_analysis_data/Test_Inpatientdata-1542969243754.csv
# ./fraud_data_analysis_data/Test-1542969243754.csv
# ./fraud_data_analysis_data/Train_Inpatientdata-1542865627584.csv
# ./fraud_data_analysis_data/Test_Outpatientdata-1542969243754.csv
# ./fraud_data_analysis_data/Train-1542865627584.csv

# %%
# Iterate over each CSV file and read it into a dataframe
for csv_file in csv_files:
    df = pd.read_csv(csv_file)
    dataframes_dict[csv_file] = df

    # Concatenate all the dataframes into a single dataframe
# combined_df = pd.concat(dataframes)

# %% [markdown]
# # Train Data's

# %%
train_outpatient_df = dataframes_dict['./fraud_data_analysis_data/Train_Outpatientdata-1542865627584.csv']
train_outpatient_df.head()
# Out:
#       BeneID    ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11002  CLM624349   2009-10-11  2009-10-11  PRV56011
# 1  BENE11003  CLM189947   2009-02-12  2009-02-12  PRV57610
# 2  BENE11003  CLM438021   2009-06-27  2009-06-27  PRV57595
# 3  BENE11004  CLM121801   2009-01-06  2009-01-06  PRV56011
# 4  BENE11004  CLM150998   2009-01-22  2009-01-22  PRV56011
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                      30          PHY326117                NaN
# 1                      80          PHY362868                NaN
# 2                      10          PHY328821                NaN
# 3                      40          PHY334319                NaN
# 4                     200          PHY403831                NaN
#
#   OtherPhysician ClmDiagnosisCode_1  ... ClmDiagnosisCode_9  \
# 0            NaN              78943  ...                NaN
# 1            NaN               6115  ...                NaN
# 2            NaN               2723  ...                NaN
# 3            NaN              71988  ...                NaN
# 4            NaN              82382  ...                NaN
#
#   ClmDiagnosisCode_10 ClmProcedureCode_1 ClmProcedureCode_2  \
# 0                 NaN                NaN                NaN
# 1                 NaN                NaN                NaN
# 2                 NaN                NaN                NaN
# 3                 NaN                NaN                NaN
# 4                 NaN                NaN                NaN
#
#   ClmProcedureCode_3 ClmProcedureCode_4 ClmProcedureCode_5 ClmProcedureCode_6  \
# 0                NaN                NaN                NaN                NaN
# 1                NaN                NaN                NaN                NaN
# 2                NaN                NaN                NaN                NaN
# 3                NaN                NaN                NaN                NaN
# 4                NaN                NaN                NaN                NaN
#
#   DeductibleAmtPaid  ClmAdmitDiagnosisCode
# 0                 0                  56409
# 1                 0                  79380
# 2                 0                    NaN
# 3                 0                    NaN
# 4                 0                  71947
#
# [5 rows x 27 columns]

# %%
train_outpatient_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 517737 entries, 0 to 517736
# Data columns (total 28 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   BeneID                  517737 non-null  object
#  1   ClaimID                 517737 non-null  object
#  2   ClaimStartDt            517737 non-null  datetime64[ns]
#  3   ClaimEndDt              517737 non-null  datetime64[ns]
#  4   Provider                517737 non-null  object
#  5   InscClaimAmtReimbursed  517737 non-null  int64
#  6   AttendingPhysician      516341 non-null  object
#  7   OperatingPhysician      90617 non-null   object
#  8   OtherPhysician          195046 non-null  object
#  9   ClmDiagnosisCode_1      507284 non-null  object
#  10  ClmDiagnosisCode_2      322357 non-null  object
#  11  ClmDiagnosisCode_3      203257 non-null  object
#  12  ClmDiagnosisCode_4      125596 non-null  object
#  13  ClmDiagnosisCode_5      74344 non-null   object
#  14  ClmDiagnosisCode_6      48756 non-null   object
#  15  ClmDiagnosisCode_7      32961 non-null   object
#  16  ClmDiagnosisCode_8      22912 non-null   object
#  17  ClmDiagnosisCode_9      14838 non-null   object
#  18  ClmDiagnosisCode_10     1083 non-null    object
#  19  ClmProcedureCode_1      162 non-null     float64
#  20  ClmProcedureCode_2      36 non-null      float64
#  21  ClmProcedureCode_3      4 non-null       float64
#  22  ClmProcedureCode_4      2 non-null       float64
#  23  ClmProcedureCode_5      0 non-null       float64
#  24  ClmProcedureCode_6      0 non-null       float64
#  25  DeductibleAmtPaid       517737 non-null  int64
#  26  ClmAdmitDiagnosisCode   105425 non-null  object
#  27  Claim_Duration          517737 non-null  timedelta64[ns]
# dtypes: datetime64[ns](2), float64(6), int64(2), object(17), timedelta64[ns](1)
# memory usage: 110.6+ MB

# %%
train_outpatient_df.shape
# Out:
# (517737, 27)

# %%
# Check for null values
null_values = train_outpatient_df.isnull()

null_values
# Out:
#         BeneID  ClaimID  ClaimStartDt  ClaimEndDt  Provider  \
# 0        False    False         False       False     False
# 1        False    False         False       False     False
# 2        False    False         False       False     False
# 3        False    False         False       False     False
# 4        False    False         False       False     False
# ...        ...      ...           ...         ...       ...
# 517732   False    False         False       False     False
# 517733   False    False         False       False     False
# 517734   False    False         False       False     False
# 517735   False    False         False       False     False
# 517736   False    False         False       False     False
#
#         InscClaimAmtReimbursed  AttendingPhysician  OperatingPhysician  \
# 0                        False               False                True
# 1                        False               False                True
# 2                        False               False                True
# 3                        False               False                True
# 4                        False               False                True
# ...                        ...                 ...                 ...
# 517732                   False               False               False
# 517733                   False               False               False
# 517734                   False               False                True
# 517735                   False               False                True
# 517736                   False               False                True
#
#         OtherPhysician  ClmDiagnosisCode_1  ...  ClmDiagnosisCode_9  \
# 0                 True               False  ...                True
# 1                 True               False  ...                True
# 2                 True               False  ...                True
# 3                 True               False  ...                True
# 4                 True               False  ...                True
# ...                ...                 ...  ...                 ...
# 517732           False               False  ...                True
# 517733            True               False  ...                True
# 517734            True               False  ...                True
# 517735           False                True  ...                True
# 517736           False               False  ...                True
#
#         ClmDiagnosisCode_10  ClmProcedureCode_1  ClmProcedureCode_2  \
# 0                      True                True                True
# 1                      True                True                True
# 2                      True                True                True
# 3                      True                True                True
# 4                      True                True                True
# ...                     ...                 ...                 ...
# 517732                 True                True                True
# 517733                 True                True                True
# 517734                 True                True                True
# 517735                 True                True                True
# 517736                 True                True                True
#
#         ClmProcedureCode_3  ClmProcedureCode_4  ClmProcedureCode_5  \
# 0                     True                True                True
# 1                     True                True                True
# 2                     True                True                True
# 3                     True                True                True
# 4                     True                True                True
# ...                    ...                 ...                 ...
# 517732                True                True                True
# 517733                True                True                True
# 517734                True                True                True
# 517735                True                True                True
# 517736                True                True                True
#
#         ClmProcedureCode_6  DeductibleAmtPaid  ClmAdmitDiagnosisCode
# 0                     True              False                  False
# 1                     True              False                  False
# 2                     True              False                   True
# 3                     True              False                   True
# 4                     True              False                  False
# ...                    ...                ...                    ...
# 517732                True              False                   True
# 517733                True              False                   True
# 517734                True              False                   True
# 517735                True              False                   True
# 517736                True              False                   True
#
# [517737 rows x 27 columns]

# %%
null_values.sum()
# Out:
# BeneID                         0
# ClaimID                        0
# ClaimStartDt                   0
# ClaimEndDt                     0
# Provider                       0
# InscClaimAmtReimbursed         0
# AttendingPhysician          1396
# OperatingPhysician        427120
# OtherPhysician            322691
# ClmDiagnosisCode_1         10453
# ClmDiagnosisCode_2        195380
# ClmDiagnosisCode_3        314480
# ClmDiagnosisCode_4        392141
# ClmDiagnosisCode_5        443393
# ClmDiagnosisCode_6        468981
# ClmDiagnosisCode_7        484776
# ClmDiagnosisCode_8        494825
# ClmDiagnosisCode_9        502899
# ClmDiagnosisCode_10       516654
# ClmProcedureCode_1        517575
# ClmProcedureCode_2        517701
# ClmProcedureCode_3        517733
# ClmProcedureCode_4        517735
# ClmProcedureCode_5        517737
# ClmProcedureCode_6        517737
# DeductibleAmtPaid              0
# ClmAdmitDiagnosisCode     412312
# dtype: int64

# %%
import seaborn as sns

# %%
sns.heatmap(pd.DataFrame(null_values.sum()), annot=True, fmt=".7g", cmap='inferno', cbar=True)
# Out:
# <AxesSubplot:>

# %%
train_outpatient_df['ClaimStartDt']
# Out:
# 0         2009-10-11
# 1         2009-02-12
# 2         2009-06-27
# 3         2009-01-06
# 4         2009-01-22
#              ...
# 517732    2009-08-06
# 517733    2009-08-29
# 517734    2009-09-24
# 517735    2009-10-18
# 517736    2009-11-17
# Name: ClaimStartDt, Length: 517737, dtype: object

# %%
train_outpatient_df['ClaimStartDt'] = pd.to_datetime(train_outpatient_df['ClaimStartDt'], format="%Y-%m-%d")
train_outpatient_df['ClaimStartDt']
# Out:
# 0        2009-10-11
# 1        2009-02-12
# 2        2009-06-27
# 3        2009-01-06
# 4        2009-01-22
#             ...
# 517732   2009-08-06
# 517733   2009-08-29
# 517734   2009-09-24
# 517735   2009-10-18
# 517736   2009-11-17
# Name: ClaimStartDt, Length: 517737, dtype: datetime64[ns]

# %%
train_outpatient_df['ClaimEndDt']
# Out:
# 0         2009-10-11
# 1         2009-02-12
# 2         2009-06-27
# 3         2009-01-06
# 4         2009-01-22
#              ...
# 517732    2009-08-06
# 517733    2009-08-29
# 517734    2009-09-24
# 517735    2009-10-18
# 517736    2009-11-18
# Name: ClaimEndDt, Length: 517737, dtype: object

# %%
train_outpatient_df['ClaimEndDt'] = pd.to_datetime(train_outpatient_df['ClaimEndDt'], format="%Y-%m-%d")
train_outpatient_df['ClaimEndDt']
# Out:
# 0        2009-10-11
# 1        2009-02-12
# 2        2009-06-27
# 3        2009-01-06
# 4        2009-01-22
#             ...
# 517732   2009-08-06
# 517733   2009-08-29
# 517734   2009-09-24
# 517735   2009-10-18
# 517736   2009-11-18
# Name: ClaimEndDt, Length: 517737, dtype: datetime64[ns]

# %%
train_outpatient_df['Claim_Duration'] = train_outpatient_df['ClaimEndDt'] - train_outpatient_df['ClaimStartDt']
train_outpatient_df['Claim_Duration'] = train_outpatient_df['Claim_Duration'].dt.days
train_outpatient_df['Claim_Duration']
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 517732    0
# 517733    0
# 517734    0
# 517735    0
# 517736    1
# Name: Claim_Duration, Length: 517737, dtype: int64

# %%
train_outpatient_df['Claim_Duration'].unique()
# Out:
# array([ 0, 20, 12,  7, 14,  1, 15,  3,  6,  2, 13,  5,  9, 18, 10, 19, 16,
#         4,  8, 17, 11, 23, 21])

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(train_outpatient_df['Claim_Duration'], bins='auto', color='blue', alpha=0.7, rwidth=0.85)

# Customize the plot
plt.grid(axis='y', alpha=0.5)
plt.xlabel('Claim duration in days')
plt.ylabel('Frequency')
plt.title('Claim duration distribution')

# Display the plot
plt.show()

# %%
# Using a context manager for plotting
with plt.style.context('seaborn'):
    plt.hist(train_outpatient_df['Claim_Duration'], bins='auto', color='blue', alpha=0.7, rwidth=0.85)
    
    # Customize the plot
    plt.grid(axis='y', alpha=0.5)
    plt.xlabel('Claim duration in days')
    plt.ylabel('Frequency')
    plt.title('Claim duration distribution')

    # Display the plot
    plt.show()

# %%
group_by_claim_day_df = train_outpatient_df.groupby(train_outpatient_df['Claim_Duration'])
group_by_claim_day_df.count().head()
group_by_claim_day_df['ClaimID'].count().head()
# Out:
# Claim_Duration
# 0    453348
# 1     11960
# 2      4366
# 3      2597
# 4      2238
# Name: ClaimID, dtype: int64

# %%
train_outpatient_df.columns
# Out:
# Index(['BeneID', 'ClaimID', 'ClaimStartDt', 'ClaimEndDt', 'Provider',
#        'InscClaimAmtReimbursed', 'AttendingPhysician', 'OperatingPhysician',
#        'OtherPhysician', 'ClmDiagnosisCode_1', 'ClmDiagnosisCode_2',
#        'ClmDiagnosisCode_3', 'ClmDiagnosisCode_4', 'ClmDiagnosisCode_5',
#        'ClmDiagnosisCode_6', 'ClmDiagnosisCode_7', 'ClmDiagnosisCode_8',
#        'ClmDiagnosisCode_9', 'ClmDiagnosisCode_10', 'ClmProcedureCode_1',
#        'ClmProcedureCode_2', 'ClmProcedureCode_3', 'ClmProcedureCode_4',
#        'ClmProcedureCode_5', 'ClmProcedureCode_6', 'DeductibleAmtPaid',
#        'ClmAdmitDiagnosisCode', 'Claim_Duration'],
#       dtype='object')

# %%
pd.DataFrame(train_outpatient_df.groupby(train_outpatient_df['Claim_Duration'])['InscClaimAmtReimbursed'].sum())
# Out:
#                 InscClaimAmtReimbursed
# Claim_Duration
# 0                            105624910
# 1                              5381060
# 2                              2227230
# 3                              1272800
# 4                              1270910
# 5                               976870
# 6                               571400
# 7                              1280020
# 8                               463190
# 9                               686930
# 10                              385090
# 11                              475220
# 12                              518670
# 13                              436950
# 14                             1183090
# 15                              370550
# 16                              558680
# 17                              299910
# 18                              426380
# 19                              357230
# 20                            23365230
# 21                               11300
# 23                              102500

# %%
pd.DataFrame(train_outpatient_df.groupby(train_outpatient_df['Claim_Duration'])['DeductibleAmtPaid'].sum())
# Out:
#                 DeductibleAmtPaid
# Claim_Duration
# 0                         1267017
# 1                           37930
# 2                           11330
# 3                            7520
# 4                            7435
# 5                            6223
# 6                            3080
# 7                            7396
# 8                            3520
# 9                            3440
# 10                           2520
# 11                           1980
# 12                           2020
# 13                           3505
# 14                           6210
# 15                           2940
# 16                           3610
# 17                           2670
# 18                           2500
# 19                           1400
# 20                          53790
# 21                              0
# 23                            876

# %%
duplicates_claimid = train_outpatient_df[train_outpatient_df['ClaimID'].duplicated()]
duplicates_claimid
# Out:
# Empty DataFrame
# Columns: [BeneID, ClaimID, ClaimStartDt, ClaimEndDt, Provider, InscClaimAmtReimbursed, AttendingPhysician, OperatingPhysician, OtherPhysician, ClmDiagnosisCode_1, ClmDiagnosisCode_2, ClmDiagnosisCode_3, ClmDiagnosisCode_4, ClmDiagnosisCode_5, ClmDiagnosisCode_6, ClmDiagnosisCode_7, ClmDiagnosisCode_8, ClmDiagnosisCode_9, ClmDiagnosisCode_10, ClmProcedureCode_1, ClmProcedureCode_2, ClmProcedureCode_3, ClmProcedureCode_4, ClmProcedureCode_5, ClmProcedureCode_6, DeductibleAmtPaid, ClmAdmitDiagnosisCode, Claim_Duration]
# Index: []
#
# [0 rows x 28 columns]

# %%
# ClaimID as a unique identifier for each claim and count the occurrences of each ClaimID in your dataset. 


claim_count = train_outpatient_df['ClaimID'].unique()
claim_count
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_62853/1453550975.py in <module>
#       2
#       3
# ----> 4 claim_count = train_outpatient_df['ClaimID'].unique()
#       5 claim_count
#
# NameError: name 'train_outpatient_df' is not defined

# %% [markdown]
# # Relationship of / to provider with  ...

# %%
pd.DataFrame(train_outpatient_df.groupby(train_outpatient_df['Provider']).count())
# Out:
#           BeneID  ClaimID  ClaimStartDt  ClaimEndDt  InscClaimAmtReimbursed  \
# Provider
# PRV51001      20       20            20          20                      20
# PRV51003      70       70            70          70                      70
# PRV51004     149      149           149         149                     149
# PRV51005    1165     1165          1165        1165                    1165
# PRV51007      69       69            69          69                      69
# ...          ...      ...           ...         ...                     ...
# PRV57759      28       28            28          28                      28
# PRV57760      22       22            22          22                      22
# PRV57761      82       82            82          82                      82
# PRV57762       1        1             1           1                       1
# PRV57763     118      118           118         118                     118
#
#           AttendingPhysician  OperatingPhysician  OtherPhysician  \
# Provider
# PRV51001                  20                   3               9
# PRV51003                  70                   5              25
# PRV51004                 149                  27              63
# PRV51005                1163                 222             478
# PRV51007                  69                  11              26
# ...                      ...                 ...             ...
# PRV57759                  28                   1              12
# PRV57760                  22                   6               9
# PRV57761                  82                  14              36
# PRV57762                   1                   0               0
# PRV57763                 118                  19              49
#
#           ClmDiagnosisCode_1  ClmDiagnosisCode_2  ...  ClmDiagnosisCode_10  \
# Provider                                          ...
# PRV51001                  19                  11  ...                    0
# PRV51003                  70                  50  ...                    1
# PRV51004                 143                  91  ...                    0
# PRV51005                1149                 723  ...                    1
# PRV51007                  69                  43  ...                    1
# ...                      ...                 ...  ...                  ...
# PRV57759                  27                  16  ...                    0
# PRV57760                  22                  11  ...                    0
# PRV57761                  82                  55  ...                    0
# PRV57762                   1                   0  ...                    0
# PRV57763                 116                  77  ...                    1
#
#           ClmProcedureCode_1  ClmProcedureCode_2  ClmProcedureCode_3  \
# Provider
# PRV51001                   0                   0                   0
# PRV51003                   0                   0                   0
# PRV51004                   0                   0                   0
# PRV51005                   0                   0                   0
# PRV51007                   0                   0                   0
# ...                      ...                 ...                 ...
# PRV57759                   0                   0                   0
# PRV57760                   0                   0                   0
# PRV57761                   0                   0                   0
# PRV57762                   0                   0                   0
# PRV57763                   0                   0                   0
#
#           ClmProcedureCode_4  ClmProcedureCode_5  ClmProcedureCode_6  \
# Provider
# PRV51001                   0                   0                   0
# PRV51003                   0                   0                   0
# PRV51004                   0                   0                   0
# PRV51005                   0                   0                   0
# PRV51007                   0                   0                   0
# ...                      ...                 ...                 ...
# PRV57759                   0                   0                   0
# PRV57760                   0                   0                   0
# PRV57761                   0                   0                   0
# PRV57762                   0                   0                   0
# PRV57763                   0                   0                   0
#
#           DeductibleAmtPaid  ClmAdmitDiagnosisCode  Claim_Duration
# Provider
# PRV51001                 20                      6              20
# PRV51003                 70                     16              70
# PRV51004                149                     28             149
# PRV51005               1165                    252            1165
# PRV51007                 69                     14              69
# ...                     ...                    ...             ...
# PRV57759                 28                      3              28
# PRV57760                 22                      7              22
# PRV57761                 82                     18              82
# PRV57762                  1                      1               1
# PRV57763                118                     19             118
#
# [5012 rows x 27 columns]

# %%
# Count of Claim submitted by each provider

pd.DataFrame(train_outpatient_df.groupby(train_outpatient_df['Provider'])['ClaimID'].count())
# Out:
#           ClaimID
# Provider
# PRV51001       20
# PRV51003       70
# PRV51004      149
# PRV51005     1165
# PRV51007       69
# ...           ...
# PRV57759       28
# PRV57760       22
# PRV57761       82
# PRV57762        1
# PRV57763      118
#
# [5012 rows x 1 columns]

# %%
pd.DataFrame(train_outpatient_df.groupby(train_outpatient_df['Provider'])['InscClaimAmtReimbursed'].sum())
# Out:
#           InscClaimAmtReimbursed
# Provider
# PRV51001                    7640
# PRV51003                   32670
# PRV51004                   52170
# PRV51005                  280910
# PRV51007                   14710
# ...                          ...
# PRV57759                   10640
# PRV57760                    4770
# PRV57761                   18470
# PRV57762                    1900
# PRV57763                   43610
#
# [5012 rows x 1 columns]

# %%
train_outpatient_df.head()
# Out:
#       BeneID    ClaimID ClaimStartDt ClaimEndDt  Provider  \
# 0  BENE11002  CLM624349   2009-10-11 2009-10-11  PRV56011
# 1  BENE11003  CLM189947   2009-02-12 2009-02-12  PRV57610
# 2  BENE11003  CLM438021   2009-06-27 2009-06-27  PRV57595
# 3  BENE11004  CLM121801   2009-01-06 2009-01-06  PRV56011
# 4  BENE11004  CLM150998   2009-01-22 2009-01-22  PRV56011
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                      30          PHY326117                NaN
# 1                      80          PHY362868                NaN
# 2                      10          PHY328821                NaN
# 3                      40          PHY334319                NaN
# 4                     200          PHY403831                NaN
#
#   OtherPhysician ClmDiagnosisCode_1  ... ClmDiagnosisCode_10  \
# 0            NaN              78943  ...                 NaN
# 1            NaN               6115  ...                 NaN
# 2            NaN               2723  ...                 NaN
# 3            NaN              71988  ...                 NaN
# 4            NaN              82382  ...                 NaN
#
#   ClmProcedureCode_1 ClmProcedureCode_2 ClmProcedureCode_3 ClmProcedureCode_4  \
# 0                NaN                NaN                NaN                NaN
# 1                NaN                NaN                NaN                NaN
# 2                NaN                NaN                NaN                NaN
# 3                NaN                NaN                NaN                NaN
# 4                NaN                NaN                NaN                NaN
#
#   ClmProcedureCode_5 ClmProcedureCode_6 DeductibleAmtPaid  \
# 0                NaN                NaN                 0
# 1                NaN                NaN                 0
# 2                NaN                NaN                 0
# 3                NaN                NaN                 0
# 4                NaN                NaN                 0
#
#   ClmAdmitDiagnosisCode  Claim_Duration
# 0                 56409          0 days
# 1                 79380          0 days
# 2                   NaN          0 days
# 3                   NaN          0 days
# 4                 71947          0 days
#
# [5 rows x 28 columns]

# %%
n_by_provider_in = train_outpatient_df.groupby('Provider').count()
n_by_provider_in
# Out:
#           BeneID  ClaimID  ClaimStartDt  ClaimEndDt  InscClaimAmtReimbursed  \
# Provider
# PRV51001       5        5             5           5                       5
# PRV51003      62       62            62          62                      62
# PRV51007       3        3             3           3                       3
# PRV51008       2        2             2           2                       2
# PRV51011       1        1             1           1                       1
# ...          ...      ...           ...         ...                     ...
# PRV57719       4        4             4           4                       4
# PRV57728       1        1             1           1                       1
# PRV57729      11       11            11          11                      11
# PRV57732      11       11            11          11                      11
# PRV57757      11       11            11          11                      11
#
#           AttendingPhysician  OperatingPhysician  OtherPhysician  AdmissionDt  \
# Provider
# PRV51001                   5                   2               1            5
# PRV51003                  62                  40               0           62
# PRV51007                   3                   1               0            3
# PRV51008                   2                   2               0            2
# PRV51011                   1                   0               0            1
# ...                      ...                 ...             ...          ...
# PRV57719                   4                   2               1            4
# PRV57728                   1                   0               1            1
# PRV57729                  11                   6               1           11
# PRV57732                  11                   8               3           11
# PRV57757                  11                   6               1           11
#
#           ClmAdmitDiagnosisCode  ...  ClmDiagnosisCode_7  ClmDiagnosisCode_8  \
# Provider                         ...
# PRV51001                      5  ...                   3                   2
# PRV51003                     62  ...                  52                  47
# PRV51007                      3  ...                   2                   1
# PRV51008                      2  ...                   1                   1
# PRV51011                      1  ...                   1                   1
# ...                         ...  ...                 ...                 ...
# PRV57719                      4  ...                   3                   3
# PRV57728                      1  ...                   0                   0
# PRV57729                     11  ...                  10                   8
# PRV57732                     11  ...                   7                   7
# PRV57757                     11  ...                   9                   7
#
#           ClmDiagnosisCode_9  ClmDiagnosisCode_10  ClmProcedureCode_1  \
# Provider
# PRV51001                   1                    0                   2
# PRV51003                  44                    4                  39
# PRV51007                   1                    0                   1
# PRV51008                   1                    0                   2
# PRV51011                   0                    0                   0
# ...                      ...                  ...                 ...
# PRV57719                   3                    1                   2
# PRV57728                   0                    0                   0
# PRV57729                   7                    1                   6
# PRV57732                   6                    1                   8
# PRV57757                   6                    0                   6
#
#           ClmProcedureCode_2  ClmProcedureCode_3  ClmProcedureCode_4  \
# Provider
# PRV51001                   1                   0                   0
# PRV51003                   9                   0                   0
# PRV51007                   0                   0                   0
# PRV51008                   0                   0                   0
# PRV51011                   0                   0                   0
# ...                      ...                 ...                 ...
# PRV57719                   1                   0                   0
# PRV57728                   0                   0                   0
# PRV57729                   0                   0                   0
# PRV57732                   1                   0                   0
# PRV57757                   1                   0                   0
#
#           ClmProcedureCode_5  ClmProcedureCode_6
# Provider
# PRV51001                   0                   0
# PRV51003                   0                   0
# PRV51007                   0                   0
# PRV51008                   0                   0
# PRV51011                   0                   0
# ...                      ...                 ...
# PRV57719                   0                   0
# PRV57728                   0                   0
# PRV57729                   0                   0
# PRV57732                   0                   0
# PRV57757                   0                   0
#
# [2092 rows x 29 columns]

# %%
train_beneficiary_df = dataframes_dict['./fraud_data_analysis_data/Train_Beneficiarydata-1542865627584.csv']
train_beneficiary_df.head()
# Out:
#       BeneID         DOB  DOD  Gender  Race RenalDiseaseIndicator  State  \
# 0  BENE11001  1943-01-01  NaN       1     1                     0     39
# 1  BENE11002  1936-09-01  NaN       2     1                     0     39
# 2  BENE11003  1936-08-01  NaN       1     1                     0     52
# 3  BENE11004  1922-07-01  NaN       1     1                     0     39
# 4  BENE11005  1935-09-01  NaN       1     1                     0     24
#
#    County  NoOfMonths_PartACov  NoOfMonths_PartBCov  ...  \
# 0     230                   12                   12  ...
# 1     280                   12                   12  ...
# 2     590                   12                   12  ...
# 3     270                   12                   12  ...
# 4     680                   12                   12  ...
#
#    ChronicCond_Depression  ChronicCond_Diabetes  ChronicCond_IschemicHeart  \
# 0                       1                     1                          1
# 1                       2                     2                          2
# 2                       2                     2                          1
# 3                       2                     1                          1
# 4                       2                     1                          2
#
#    ChronicCond_Osteoporasis  ChronicCond_rheumatoidarthritis  \
# 0                         2                                1
# 1                         2                                2
# 2                         2                                2
# 3                         1                                1
# 4                         2                                2
#
#    ChronicCond_stroke  IPAnnualReimbursementAmt  IPAnnualDeductibleAmt  \
# 0                   1                     36000                   3204
# 1                   2                         0                      0
# 2                   2                         0                      0
# 3                   2                         0                      0
# 4                   2                         0                      0
#
#    OPAnnualReimbursementAmt  OPAnnualDeductibleAmt
# 0                        60                     70
# 1                        30                     50
# 2                        90                     40
# 3                      1810                    760
# 4                      1790                   1200
#
# [5 rows x 25 columns]

# %%
train_inpatient_df = dataframes_dict['./fraud_data_analysis_data/Train_Inpatientdata-1542865627584.csv']
train_inpatient_df.head()
# Out:
#       BeneID   ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11001  CLM46614   2009-04-12  2009-04-18  PRV55912
# 1  BENE11001  CLM66048   2009-08-31  2009-09-02  PRV55907
# 2  BENE11001  CLM68358   2009-09-17  2009-09-20  PRV56046
# 3  BENE11011  CLM38412   2009-02-14  2009-02-22  PRV52405
# 4  BENE11014  CLM63689   2009-08-13  2009-08-30  PRV56614
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                   26000          PHY390922                NaN
# 1                    5000          PHY318495          PHY318495
# 2                    5000          PHY372395                NaN
# 3                    5000          PHY369659          PHY392961
# 4                   10000          PHY379376          PHY398258
#
#   OtherPhysician AdmissionDt  ... ClmDiagnosisCode_7  ClmDiagnosisCode_8  \
# 0            NaN  2009-04-12  ...               2724               19889
# 1            NaN  2009-08-31  ...                NaN                 NaN
# 2      PHY324689  2009-09-17  ...                NaN                 NaN
# 3      PHY349768  2009-02-14  ...              25062               40390
# 4            NaN  2009-08-13  ...               5119               29620
#
#   ClmDiagnosisCode_9 ClmDiagnosisCode_10 ClmProcedureCode_1  \
# 0               5849                 NaN                NaN
# 1                NaN                 NaN             7092.0
# 2                NaN                 NaN                NaN
# 3               4019                 NaN              331.0
# 4              20300                 NaN             3893.0
#
#   ClmProcedureCode_2 ClmProcedureCode_3 ClmProcedureCode_4 ClmProcedureCode_5  \
# 0                NaN                NaN                NaN                NaN
# 1                NaN                NaN                NaN                NaN
# 2                NaN                NaN                NaN                NaN
# 3                NaN                NaN                NaN                NaN
# 4                NaN                NaN                NaN                NaN
#
#   ClmProcedureCode_6
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
#
# [5 rows x 30 columns]

# %%
n_by_provider_in = train_inpatient_df.groupby('Provider').count()
n_by_provider_in
# Out:
#           BeneID  ClaimID  ClaimStartDt  ClaimEndDt  InscClaimAmtReimbursed  \
# Provider
# PRV51001       5        5             5           5                       5
# PRV51003      62       62            62          62                      62
# PRV51007       3        3             3           3                       3
# PRV51008       2        2             2           2                       2
# PRV51011       1        1             1           1                       1
# ...          ...      ...           ...         ...                     ...
# PRV57719       4        4             4           4                       4
# PRV57728       1        1             1           1                       1
# PRV57729      11       11            11          11                      11
# PRV57732      11       11            11          11                      11
# PRV57757      11       11            11          11                      11
#
#           AttendingPhysician  OperatingPhysician  OtherPhysician  AdmissionDt  \
# Provider
# PRV51001                   5                   2               1            5
# PRV51003                  62                  40               0           62
# PRV51007                   3                   1               0            3
# PRV51008                   2                   2               0            2
# PRV51011                   1                   0               0            1
# ...                      ...                 ...             ...          ...
# PRV57719                   4                   2               1            4
# PRV57728                   1                   0               1            1
# PRV57729                  11                   6               1           11
# PRV57732                  11                   8               3           11
# PRV57757                  11                   6               1           11
#
#           ClmAdmitDiagnosisCode  ...  ClmDiagnosisCode_7  ClmDiagnosisCode_8  \
# Provider                         ...
# PRV51001                      5  ...                   3                   2
# PRV51003                     62  ...                  52                  47
# PRV51007                      3  ...                   2                   1
# PRV51008                      2  ...                   1                   1
# PRV51011                      1  ...                   1                   1
# ...                         ...  ...                 ...                 ...
# PRV57719                      4  ...                   3                   3
# PRV57728                      1  ...                   0                   0
# PRV57729                     11  ...                  10                   8
# PRV57732                     11  ...                   7                   7
# PRV57757                     11  ...                   9                   7
#
#           ClmDiagnosisCode_9  ClmDiagnosisCode_10  ClmProcedureCode_1  \
# Provider
# PRV51001                   1                    0                   2
# PRV51003                  44                    4                  39
# PRV51007                   1                    0                   1
# PRV51008                   1                    0                   2
# PRV51011                   0                    0                   0
# ...                      ...                  ...                 ...
# PRV57719                   3                    1                   2
# PRV57728                   0                    0                   0
# PRV57729                   7                    1                   6
# PRV57732                   6                    1                   8
# PRV57757                   6                    0                   6
#
#           ClmProcedureCode_2  ClmProcedureCode_3  ClmProcedureCode_4  \
# Provider
# PRV51001                   1                   0                   0
# PRV51003                   9                   0                   0
# PRV51007                   0                   0                   0
# PRV51008                   0                   0                   0
# PRV51011                   0                   0                   0
# ...                      ...                 ...                 ...
# PRV57719                   1                   0                   0
# PRV57728                   0                   0                   0
# PRV57729                   0                   0                   0
# PRV57732                   1                   0                   0
# PRV57757                   1                   0                   0
#
#           ClmProcedureCode_5  ClmProcedureCode_6
# Provider
# PRV51001                   0                   0
# PRV51003                   0                   0
# PRV51007                   0                   0
# PRV51008                   0                   0
# PRV51011                   0                   0
# ...                      ...                 ...
# PRV57719                   0                   0
# PRV57728                   0                   0
# PRV57729                   0                   0
# PRV57732                   0                   0
# PRV57757                   0                   0
#
# [2092 rows x 29 columns]

# %%
train_df = dataframes_dict['./fraud_data_analysis_data/Train-1542865627584.csv']
train_df.head()
# Out:
#    Provider PotentialFraud
# 0  PRV51001             No
# 1  PRV51003            Yes
# 2  PRV51004             No
# 3  PRV51005            Yes
# 4  PRV51007             No

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5410 entries, 0 to 5409
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Provider        5410 non-null   object
#  1   PotentialFraud  5410 non-null   object
# dtypes: object(2)
# memory usage: 84.7+ KB

# %% [markdown]
# # Test

# %%
test_df = dataframes_dict['./fraud_data_analysis_data/Test-1542969243754.csv']
test_df.head()
# Out:
#    Provider
# 0  PRV51002
# 1  PRV51006
# 2  PRV51009
# 3  PRV51010
# 4  PRV51018

# %%
test_beneficiary_df = dataframes_dict['./fraud_data_analysis_data/Test_Beneficiarydata-1542969243754.csv']

# %%
test_beneficiary_df.head()
# Out:
#       BeneID         DOB         DOD  Gender  Race RenalDiseaseIndicator  \
# 0  BENE11001  1943-01-01         NaN       1     1                     0
# 1  BENE11007  1940-09-01  2009-12-01       1     2                     0
# 2  BENE11010  1936-07-01         NaN       2     1                     0
# 3  BENE11011  1914-03-01         NaN       2     2                     0
# 4  BENE11014  1938-04-01         NaN       2     1                     Y
#
#    State  County  NoOfMonths_PartACov  NoOfMonths_PartBCov  ...  \
# 0     39     230                   12                   12  ...
# 1     45     610                   12                   12  ...
# 2     41      30                   12                   12  ...
# 3      1     360                   12                   12  ...
# 4     45     780                   12                   12  ...
#
#    ChronicCond_Depression  ChronicCond_Diabetes  ChronicCond_IschemicHeart  \
# 0                       1                     1                          1
# 1                       2                     1                          2
# 2                       2                     1                          1
# 3                       1                     1                          2
# 4                       1                     2                          1
#
#    ChronicCond_Osteoporasis  ChronicCond_rheumatoidarthritis  \
# 0                         2                                1
# 1                         1                                1
# 2                         1                                2
# 3                         2                                1
# 4                         2                                2
#
#    ChronicCond_stroke  IPAnnualReimbursementAmt  IPAnnualDeductibleAmt  \
# 0                   1                     36000                   3204
# 1                   2                         0                      0
# 2                   2                         0                      0
# 3                   1                      5000                   1068
# 4                   2                     21260                   2136
#
#    OPAnnualReimbursementAmt  OPAnnualDeductibleAmt
# 0                        60                     70
# 1                      1490                    160
# 2                      1170                    660
# 3                       250                    320
# 4                       120                    100
#
# [5 rows x 25 columns]

# %%
test_inpatient_data_df = dataframes_dict['./fraud_data_analysis_data/Test_Inpatientdata-1542969243754.csv']
test_inpatient_data_df.head()
# Out:
#       BeneID   ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11014  CLM67387   2009-09-09  2009-09-16  PRV57070
# 1  BENE11017  CLM31237   2008-12-25  2009-01-08  PRV54750
# 2  BENE11026  CLM78930   2009-12-09  2009-12-13  PRV53758
# 3  BENE11031  CLM56810   2009-06-23  2009-07-06  PRV55825
# 4  BENE11085  CLM34625   2009-01-20  2009-01-31  PRV52338
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                    9000          PHY317786          PHY427017
# 1                   14000          PHY314656          PHY426644
# 2                    2000          PHY349495                NaN
# 3                   16000          PHY429538          PHY371893
# 4                   19000          PHY397161                NaN
#
#   OtherPhysician AdmissionDt  ... ClmDiagnosisCode_7  ClmDiagnosisCode_8  \
# 0            NaN  2009-09-09  ...               5990                 570
# 1            NaN  2008-12-25  ...               4549               29570
# 2            NaN  2009-12-09  ...              78650                7813
# 3            NaN  2009-06-23  ...               4254               41400
# 4            NaN  2009-01-20  ...              V6109                7242
#
#   ClmDiagnosisCode_9 ClmDiagnosisCode_10 ClmProcedureCode_1  \
# 0              41071                4280             4443.0
# 1              34831                 NaN             5551.0
# 2               4254                 NaN                NaN
# 3               5849               41401             8152.0
# 4                NaN                 NaN                NaN
#
#   ClmProcedureCode_2 ClmProcedureCode_3 ClmProcedureCode_4 ClmProcedureCode_5  \
# 0             5849.0                NaN                NaN                NaN
# 1                NaN                NaN                NaN                NaN
# 2                NaN                NaN                NaN                NaN
# 3             3320.0                NaN                NaN                NaN
# 4                NaN                NaN                NaN                NaN
#
#   ClmProcedureCode_6
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
#
# [5 rows x 30 columns]

# %%
test_outpatient_data_df = dataframes_dict['./fraud_data_analysis_data/Test_Outpatientdata-1542969243754.csv']
test_outpatient_data_df.head()
# Out:
#       BeneID    ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11001  CLM392397   2009-06-02  2009-06-02  PRV55962
# 1  BENE11001  CLM430760   2009-06-23  2009-06-23  PRV56112
# 2  BENE11007  CLM233081   2009-03-07  2009-03-07  PRV56979
# 3  BENE11007  CLM496381   2009-07-29  2009-07-29  PRV56573
# 4  BENE11007  CLM521391   2009-08-12  2009-08-12  PRV56573
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                      30          PHY347633                NaN
# 1                      30          PHY381777                NaN
# 2                     200          PHY425311                NaN
# 3                      10          PHY393253          PHY347995
# 4                      10          PHY417685                NaN
#
#   OtherPhysician ClmDiagnosisCode_1  ... ClmDiagnosisCode_9  \
# 0      PHY347633              V5832  ...                NaN
# 1      PHY381777               9594  ...                NaN
# 2      PHY425311               7248  ...                NaN
# 3            NaN              58889  ...                NaN
# 4      PHY382041               V666  ...                NaN
#
#   ClmDiagnosisCode_10 ClmProcedureCode_1 ClmProcedureCode_2  \
# 0                 NaN                NaN                NaN
# 1                 NaN                NaN                NaN
# 2                 NaN                NaN                NaN
# 3                 NaN                NaN                NaN
# 4                 NaN                NaN                NaN
#
#   ClmProcedureCode_3 ClmProcedureCode_4 ClmProcedureCode_5 ClmProcedureCode_6  \
# 0                NaN                NaN                NaN                NaN
# 1                NaN                NaN                NaN                NaN
# 2                NaN                NaN                NaN                NaN
# 3                NaN                NaN                NaN                NaN
# 4                NaN                NaN                NaN                NaN
#
#   DeductibleAmtPaid  ClmAdmitDiagnosisCode
# 0                 0                    NaN
# 1                 0                    NaN
# 2                 0                    NaN
# 3                 0                   5939
# 4                 0                    NaN
#
# [5 rows x 27 columns]

# %%
test_outpatient_data_df['Provider']
# Out:
# 0         PRV55962
# 1         PRV56112
# 2         PRV56979
# 3         PRV56573
# 4         PRV56573
#             ...
# 125836    PRV55485
# 125837    PRV55485
# 125838    PRV55485
# 125839    PRV55889
# 125840    PRV52983
# Name: Provider, Length: 125841, dtype: object

# %%
len(test_inpatient_data_df['Provider'].unique())
# Out:
# 520

# %%
n_by_provider = test_inpatient_data_df.groupby('Provider').count()
n_by_provider
# Out:
#           BeneID  ClaimID  ClaimStartDt  ClaimEndDt  InscClaimAmtReimbursed  \
# Provider
# PRV51009       2        2             2           2                       2
# PRV51010       6        6             6           6                       6
# PRV51020       2        2             2           2                       2
# PRV51022       7        7             7           7                       7
# PRV51033       1        1             1           1                       1
# ...          ...      ...           ...         ...                     ...
# PRV57608       6        6             6           6                       6
# PRV57644       2        2             2           2                       2
# PRV57649       1        1             1           1                       1
# PRV57666       9        9             9           9                       9
# PRV57698       1        1             1           1                       1
#
#           AttendingPhysician  OperatingPhysician  OtherPhysician  AdmissionDt  \
# Provider
# PRV51009                   2                   2               0            2
# PRV51010                   6                   3               0            6
# PRV51020                   2                   1               0            2
# PRV51022                   7                   6               2            7
# PRV51033                   1                   0               0            1
# ...                      ...                 ...             ...          ...
# PRV57608                   6                   4               0            6
# PRV57644                   2                   1               2            2
# PRV57649                   1                   0               0            1
# PRV57666                   9                   5               2            9
# PRV57698                   1                   1               0            1
#
#           ClmAdmitDiagnosisCode  ...  ClmDiagnosisCode_7  ClmDiagnosisCode_8  \
# Provider                         ...
# PRV51009                      2  ...                   1                   1
# PRV51010                      6  ...                   4                   2
# PRV51020                      2  ...                   2                   2
# PRV51022                      7  ...                   5                   5
# PRV51033                      1  ...                   0                   0
# ...                         ...  ...                 ...                 ...
# PRV57608                      6  ...                   4                   4
# PRV57644                      2  ...                   1                   1
# PRV57649                      1  ...                   0                   0
# PRV57666                      9  ...                   8                   8
# PRV57698                      1  ...                   1                   1
#
#           ClmDiagnosisCode_9  ClmDiagnosisCode_10  ClmProcedureCode_1  \
# Provider
# PRV51009                   1                    1                   2
# PRV51010                   2                    0                   3
# PRV51020                   2                    1                   1
# PRV51022                   4                    1                   6
# PRV51033                   0                    0                   0
# ...                      ...                  ...                 ...
# PRV57608                   4                    0                   4
# PRV57644                   1                    0                   1
# PRV57649                   0                    0                   0
# PRV57666                   6                    0                   5
# PRV57698                   1                    0                   1
#
#           ClmProcedureCode_2  ClmProcedureCode_3  ClmProcedureCode_4  \
# Provider
# PRV51009                   1                   0                   0
# PRV51010                   0                   0                   0
# PRV51020                   0                   0                   0
# PRV51022                   1                   0                   0
# PRV51033                   0                   0                   0
# ...                      ...                 ...                 ...
# PRV57608                   0                   0                   0
# PRV57644                   0                   0                   0
# PRV57649                   0                   0                   0
# PRV57666                   2                   0                   0
# PRV57698                   0                   0                   0
#
#           ClmProcedureCode_5  ClmProcedureCode_6
# Provider
# PRV51009                   0                   0
# PRV51010                   0                   0
# PRV51020                   0                   0
# PRV51022                   0                   0
# PRV51033                   0                   0
# ...                      ...                 ...
# PRV57608                   0                   0
# PRV57644                   0                   0
# PRV57649                   0                   0
# PRV57666                   0                   0
# PRV57698                   0                   0
#
# [520 rows x 29 columns]

# %% [markdown]
# # List

# %%
# Create an empty list to store the dataframes
dataframes = []

# Iterate over each CSV file and read it into a dataframe
for csv_file in csv_files:
    df = pd.read_csv(csv_file)
    dataframes.append(df)

# %%
# Assign each dataframe to a separate variable
test_beneficiary_df = dataframes[2]
test_inpatient_data_df = dataframes[3]
test_outpatient_data_df = dataframes[6]

# %%
 test_beneficiary_df.head()
# Out:
#       BeneID         DOB         DOD  Gender  Race RenalDiseaseIndicator  \
# 0  BENE11001  1943-01-01         NaN       1     1                     0
# 1  BENE11007  1940-09-01  2009-12-01       1     2                     0
# 2  BENE11010  1936-07-01         NaN       2     1                     0
# 3  BENE11011  1914-03-01         NaN       2     2                     0
# 4  BENE11014  1938-04-01         NaN       2     1                     Y
#
#    State  County  NoOfMonths_PartACov  NoOfMonths_PartBCov  ...  \
# 0     39     230                   12                   12  ...
# 1     45     610                   12                   12  ...
# 2     41      30                   12                   12  ...
# 3      1     360                   12                   12  ...
# 4     45     780                   12                   12  ...
#
#    ChronicCond_Depression  ChronicCond_Diabetes  ChronicCond_IschemicHeart  \
# 0                       1                     1                          1
# 1                       2                     1                          2
# 2                       2                     1                          1
# 3                       1                     1                          2
# 4                       1                     2                          1
#
#    ChronicCond_Osteoporasis  ChronicCond_rheumatoidarthritis  \
# 0                         2                                1
# 1                         1                                1
# 2                         1                                2
# 3                         2                                1
# 4                         2                                2
#
#    ChronicCond_stroke  IPAnnualReimbursementAmt  IPAnnualDeductibleAmt  \
# 0                   1                     36000                   3204
# 1                   2                         0                      0
# 2                   2                         0                      0
# 3                   1                      5000                   1068
# 4                   2                     21260                   2136
#
#    OPAnnualReimbursementAmt  OPAnnualDeductibleAmt
# 0                        60                     70
# 1                      1490                    160
# 2                      1170                    660
# 3                       250                    320
# 4                       120                    100
#
# [5 rows x 25 columns]

# %%
test_inpatient_data_df.head()
# Out:
#       BeneID   ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11014  CLM67387   2009-09-09  2009-09-16  PRV57070
# 1  BENE11017  CLM31237   2008-12-25  2009-01-08  PRV54750
# 2  BENE11026  CLM78930   2009-12-09  2009-12-13  PRV53758
# 3  BENE11031  CLM56810   2009-06-23  2009-07-06  PRV55825
# 4  BENE11085  CLM34625   2009-01-20  2009-01-31  PRV52338
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                    9000          PHY317786          PHY427017
# 1                   14000          PHY314656          PHY426644
# 2                    2000          PHY349495                NaN
# 3                   16000          PHY429538          PHY371893
# 4                   19000          PHY397161                NaN
#
#   OtherPhysician AdmissionDt  ... ClmDiagnosisCode_7  ClmDiagnosisCode_8  \
# 0            NaN  2009-09-09  ...               5990                 570
# 1            NaN  2008-12-25  ...               4549               29570
# 2            NaN  2009-12-09  ...              78650                7813
# 3            NaN  2009-06-23  ...               4254               41400
# 4            NaN  2009-01-20  ...              V6109                7242
#
#   ClmDiagnosisCode_9 ClmDiagnosisCode_10 ClmProcedureCode_1  \
# 0              41071                4280             4443.0
# 1              34831                 NaN             5551.0
# 2               4254                 NaN                NaN
# 3               5849               41401             8152.0
# 4                NaN                 NaN                NaN
#
#   ClmProcedureCode_2 ClmProcedureCode_3 ClmProcedureCode_4 ClmProcedureCode_5  \
# 0             5849.0                NaN                NaN                NaN
# 1                NaN                NaN                NaN                NaN
# 2                NaN                NaN                NaN                NaN
# 3             3320.0                NaN                NaN                NaN
# 4                NaN                NaN                NaN                NaN
#
#   ClmProcedureCode_6
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
#
# [5 rows x 30 columns]

# %%
test_outpatient_data_df.head()
# Out:
#       BeneID    ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11001  CLM392397   2009-06-02  2009-06-02  PRV55962
# 1  BENE11001  CLM430760   2009-06-23  2009-06-23  PRV56112
# 2  BENE11007  CLM233081   2009-03-07  2009-03-07  PRV56979
# 3  BENE11007  CLM496381   2009-07-29  2009-07-29  PRV56573
# 4  BENE11007  CLM521391   2009-08-12  2009-08-12  PRV56573
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                      30          PHY347633                NaN
# 1                      30          PHY381777                NaN
# 2                     200          PHY425311                NaN
# 3                      10          PHY393253          PHY347995
# 4                      10          PHY417685                NaN
#
#   OtherPhysician ClmDiagnosisCode_1  ... ClmDiagnosisCode_9  \
# 0      PHY347633              V5832  ...                NaN
# 1      PHY381777               9594  ...                NaN
# 2      PHY425311               7248  ...                NaN
# 3            NaN              58889  ...                NaN
# 4      PHY382041               V666  ...                NaN
#
#   ClmDiagnosisCode_10 ClmProcedureCode_1 ClmProcedureCode_2  \
# 0                 NaN                NaN                NaN
# 1                 NaN                NaN                NaN
# 2                 NaN                NaN                NaN
# 3                 NaN                NaN                NaN
# 4                 NaN                NaN                NaN
#
#   ClmProcedureCode_3 ClmProcedureCode_4 ClmProcedureCode_5 ClmProcedureCode_6  \
# 0                NaN                NaN                NaN                NaN
# 1                NaN                NaN                NaN                NaN
# 2                NaN                NaN                NaN                NaN
# 3                NaN                NaN                NaN                NaN
# 4                NaN                NaN                NaN                NaN
#
#   DeductibleAmtPaid  ClmAdmitDiagnosisCode
# 0                 0                    NaN
# 1                 0                    NaN
# 2                 0                    NaN
# 3                 0                   5939
# 4                 0                    NaN
#
# [5 rows x 27 columns]
